# %%
import os, fnmatch

# %%
# with open('C:/Users/tranq/Desktop/QGIS Projects/LANDSAT Land Classification/LC08_L1TP_113037_20230502_20230509_02_T1_MTL.txt') as f:
#     lines = f.readlines()
#     f.close()
    
# # Reads the txt file
# lines
# Out:
# ['GROUP = LANDSAT_METADATA_FILE\n',
#  '  GROUP = PRODUCT_CONTENTS\n',
#  '    ORIGIN = "Image courtesy of the U.S. Geological Survey"\n',
#  '    DIGITAL_OBJECT_IDENTIFIER = "https://doi.org/10.5066/P975CC9B"\n',
#  '    LANDSAT_PRODUCT_ID = "LC08_L1TP_113037_20230502_20230509_02_T1"\n',
#  '    PROCESSING_LEVEL = "L1TP"\n',
#  '    COLLECTION_NUMBER = 02\n',
#  '    COLLECTION_CATEGORY = "T1"\n',
#  '    OUTPUT_FORMAT = "GEOTIFF"\n',
#  '    FILE_NAME_BAND_1 = "LC08_L1TP_113037_20230502_20230509_02_T1_B1.TIF"\n',
#  '    FILE_NAME_BAND_2 = "LC08_L1TP_113037_20230502_20230509_02_T1_B2.TIF"\n',
#  '    FILE_NAME_BAND_3 = "LC08_L1TP_113037_20230502_20230509_02_T1_B3.TIF"\n',
#  '    FILE_NAME_BAND_4 = "LC08_L1TP_113037_20230502_20230509_02_T1_B4.TIF"\n',
#  '    FILE_NAME_BAND_5 = "LC08_L1TP_113037_20230502_20230509_02_T1_B5.TIF"\n',
#  '    FILE_NAME_BAND_6 = "LC08_L1TP_113037_20230502_20230509_02_T1_B6.TIF"\n',
# ...
